# %%
import pandas as pd

ref_df = pd.read_csv("s3://collegebasketballinsiders/officials-analysis/officials.csv")

# %%
officials = ["Damien Richard", "Marcus Hawkins" "John Johnson"]

ref_df[ref_df['ref'].isin(officials)]
# Out:
#      Unnamed: 0             ref  games_officiated  foul_propensity_z  \
# 156         156  Damien Richard                45           1.046953
#
#      home_bias_z  points_effect_z  foul_propensity_z_rank  home_bias_z_rank  \
# 156     1.374349        -0.822791                   151.0              64.0
#
#      points_effect_z_rank
# 156                 583.0
