# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 1. The URL you want to scrape
url = "https://www.espn.com/mens-college-basketball/scoreboard/_/date/20250208/group/50"

# 2. Send a GET request with a browser-like user agent
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/119.0.0.0 Safari/537.36"
    )
}
response = requests.get(url, headers=headers)

# 3. Parse the HTML
soup = BeautifulSoup(response.text, "html.parser")

# %%
import os
import re
import json
from datetime import datetime, timedelta

import requests
from bs4 import BeautifulSoup
import pandas as pd

# ---------------- Config ----------------
START_DATE = "20241101"  # inclusive
END_DATE   = "20250313"  # inclusive
GROUP = 50               # 50 = NCAA Division I
OUT_DIR = "box-score-ids"
OVERWRITE = False        # True to overwrite existing daily files
PAUSE_SECONDS = 3.4      # be polite (optional)


HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/119.0.0.0 Safari/537.36"
    )
}

def fetch_games_api(date_yyyymmdd: str, group: int = GROUP) -> pd.DataFrame:
    """Preferred: ESPN public JSON API (no HTML parsing)."""
    url = (
        "https://site.api.espn.com/apis/v2/sports/basketball/mens-college-basketball/"
        f"scoreboard?dates={date_yyyymmdd}&groups={group}"
    )
    r = requests.get(url, headers=HEADERS, timeout=30)
    r.raise_for_status()
    data = r.json()

    rows = []
    for e in data.get("events", []):
        gid = e.get("id")
        comp = (e.get("competitions") or [{}])[0]
        comps = comp.get("competitors", [])
        home = next((c for c in comps if c.get("homeAway") == "home"), {})
        away = next((c for c in comps if c.get("homeAway") == "away"), {})
        rows.append({
            "game_id": gid,
            "home_team": home.get("team", {}).get("displayName"),
            "away_team": away.get("team", {}).get("displayName"),
        })
    return pd.DataFrame(rows)

def fetch_scoreboard_html(date_yyyymmdd: str, group: int = GROUP) -> str:
    """Fallback: fetch the scoreboard HTML for the date/group."""
    url = f"https://www.espn.com/mens-college-basketball/scoreboard/_/date/{date_yyyymmdd}/group/{group}"
    r = requests.get(url, headers=HEADERS, timeout=30)
    r.raise_for_status()
    return r.text

def parse_games_from_html(html: str) -> pd.DataFrame:
    """
    Parse game blocks from server-rendered DOM.
    <section class="Scoreboard" id="<game_id>">…</section>
    """
    soup = BeautifulSoup(html, "html.parser")
    games = []

    # Primary: section blocks with game id
    for sec in soup.select("section.Scoreboard[id]"):
        gid = sec.get("id")
        away = sec.select_one(".ScoreboardScoreCell__Item--away .ScoreCell__TeamName--shortDisplayName")
        home = sec.select_one(".ScoreboardScoreCell__Item--home .ScoreCell__TeamName--shortDisplayName")
        games.append({
            "game_id": gid,
            "home_team": home.get_text(strip=True) if home else None,
            "away_team": away.get_text(strip=True) if away else None,
        })

    # Secondary: backup to anchor pattern if nothing found
    if not games:
        for a in soup.find_all("a", href=True):
            m = re.search(r"/mens-college-basketball/game/_/gameId/(\d+)", a["href"])
            if m:
                games.append({"game_id": m.group(1), "home_team": None, "away_team": None})

    return pd.DataFrame(games)

def get_games_for_date(date_yyyymmdd: str, group: int = GROUP) -> pd.DataFrame:
    """Try API first; if empty/error, fall back to HTML."""
    # API path
    try:
        df_api = fetch_games_api(date_yyyymmdd, group=group)
        if not df_api.empty:
            df_api.insert(0, "date", date_yyyymmdd)
            return df_api
    except Exception:
        pass

    # HTML fallback
    try:
        html = fetch_scoreboard_html(date_yyyymmdd, group=group)
        df_html = parse_games_from_html(html)
        if not df_html.empty:
            df_html.insert(0, "date", date_yyyymmdd)
        return df_html
    except Exception:
        return pd.DataFrame()

def daterange(start_yyyymmdd: str, end_yyyymmdd: str):
    start = datetime.strptime(start_yyyymmdd, "%Y%m%d")
    end = datetime.strptime(end_yyyymmdd, "%Y%m%d")
    d = start
    while d <= end:
        yield d.strftime("%Y%m%d")
        d += timedelta(days=1)

def main():
    os.makedirs(OUT_DIR, exist_ok=True)
    total_days = 0
    total_games = 0

    for day in daterange(START_DATE, END_DATE):
        out_path = os.path.join(OUT_DIR, f"espn_ncaam_box_scores_{day}.csv")
        if os.path.exists(out_path) and not OVERWRITE:
            print(f"⏭️  {day}: exists, skipping (set OVERWRITE=True to redo)")
            continue

        try:
            df = get_games_for_date(day, group=GROUP)
            if df is None or df.empty:
                print(f"— {day}: no games")
            else:
                df.to_csv(out_path, index=False)
                total_days += 1
                total_games += len(df)
                print(f"✅ {day}: saved {len(df)} games → {out_path}")
        except Exception as e:
            print(f"❌ {day}: ERROR {e}")

        # be polite to the server
        if PAUSE_SECONDS:
            try:
                import time
                time.sleep(PAUSE_SECONDS)
            except Exception:
                pass

    print(f"\nDone. Wrote {total_games} games across {total_days} days into '{OUT_DIR}/'.")

# %%
main()
# Out:
# — 20241101: no games
# — 20241102: no games
# — 20241103: no games
# ✅ 20241104: saved 100 games → box-score-ids/espn_ncaam_box_scores_20241104.csv
# ✅ 20241105: saved 11 games → box-score-ids/espn_ncaam_box_scores_20241105.csv
# ✅ 20241106: saved 37 games → box-score-ids/espn_ncaam_box_scores_20241106.csv
# ✅ 20241107: saved 42 games → box-score-ids/espn_ncaam_box_scores_20241107.csv
# ✅ 20241108: saved 80 games → box-score-ids/espn_ncaam_box_scores_20241108.csv
# ✅ 20241109: saved 64 games → box-score-ids/espn_ncaam_box_scores_20241109.csv
# ✅ 20241110: saved 29 games → box-score-ids/espn_ncaam_box_scores_20241110.csv
# ✅ 20241111: saved 42 games → box-score-ids/espn_ncaam_box_scores_20241111.csv
# ✅ 20241112: saved 79 games → box-score-ids/espn_ncaam_box_scores_20241112.csv
# ✅ 20241113: saved 55 games → box-score-ids/espn_ncaam_box_scores_20241113.csv
# ✅ 20241114: saved 26 games → box-score-ids/espn_ncaam_box_scores_20241114.csv
# ✅ 20241115: saved 50 games → box-score-ids/espn_ncaam_box_scores_20241115.csv
# ✅ 20241116: saved 82 games → box-score-ids/espn_ncaam_box_scores_20241116.csv
# ✅ 20241117: saved 36 games → box-score-ids/espn_ncaam_box_scores_20241117.csv
# ✅ 20241118: saved 31 games → box-score-ids/espn_ncaam_box_scores_20241118.csv
# ✅ 20241119: saved 54 games → box-score-ids/espn_ncaam_box_scores_20241119.csv
# ✅ 20241120: saved 47 games → box-score-ids/espn_ncaam_box_scores_20241120.csv
# ✅ 20241121: saved 44 games → box-score-ids/espn_ncaam_box_scores_20241121.csv
# ✅ 20241122: saved 82 games → box-score-ids/espn_ncaam_box_scores_20241122.csv
# ✅ 20241123: saved 56 games → box-score-ids/espn_ncaam_box_scores_20241123.csv
# ✅ 20241124: saved 54 games → box-score-ids/espn_ncaam_box_scores_20241124.csv
# ✅ 20241125: saved 57 games → box-score-ids/espn_ncaam_box_scores_20241125.csv
# ✅ 20241126: saved 64 games → box-score-ids/espn_ncaam_box_scores_20241126.csv
# ✅ 20241127: saved 70 games → box-score-ids/espn_ncaam_box_scores_20241127.csv
# ✅ 20241128: saved 21 games → box-score-ids/espn_ncaam_box_scores_20241128.csv
# ✅ 20241129: saved 56 games → box-score-ids/espn_ncaam_box_scores_20241129.csv
# ✅ 20241130: saved 68 games → box-score-ids/espn_ncaam_box_scores_20241130.csv
# ✅ 20241201: saved 34 games → box-score-ids/espn_ncaam_box_scores_20241201.csv
# ✅ 20241202: saved 16 games → box-score-ids/espn_ncaam_box_scores_20241202.csv
# ✅ 20241203: saved 56 games → box-score-ids/espn_ncaam_box_scores_20241203.csv
# ✅ 20241204: saved 67 games → box-score-ids/espn_ncaam_box_scores_20241204.csv
# ✅ 20241205: saved 26 games → box-score-ids/espn_ncaam_box_scores_20241205.csv
# ✅ 20241206: saved 22 games → box-score-ids/espn_ncaam_box_scores_20241206.csv
# ✅ 20241207: saved 100 games → box-score-ids/espn_ncaam_box_scores_20241207.csv
# ✅ 20241208: saved 39 games → box-score-ids/espn_ncaam_box_scores_20241208.csv
# ✅ 20241209: saved 8 games → box-score-ids/espn_ncaam_box_scores_20241209.csv
# ✅ 20241210: saved 37 games → box-score-ids/espn_ncaam_box_scores_20241210.csv
# ✅ 20241211: saved 28 games → box-score-ids/espn_ncaam_box_scores_20241211.csv
# ✅ 20241212: saved 10 games → box-score-ids/espn_ncaam_box_scores_20241212.csv
# ✅ 20241213: saved 10 games → box-score-ids/espn_ncaam_box_scores_20241213.csv
# ✅ 20241214: saved 97 games → box-score-ids/espn_ncaam_box_scores_20241214.csv
# ✅ 20241215: saved 40 games → box-score-ids/espn_ncaam_box_scores_20241215.csv
# ✅ 20241216: saved 18 games → box-score-ids/espn_ncaam_box_scores_20241216.csv
# ✅ 20241217: saved 48 games → box-score-ids/espn_ncaam_box_scores_20241217.csv
# ✅ 20241218: saved 64 games → box-score-ids/espn_ncaam_box_scores_20241218.csv
# ✅ 20241219: saved 26 games → box-score-ids/espn_ncaam_box_scores_20241219.csv
# ✅ 20241220: saved 23 games → box-score-ids/espn_ncaam_box_scores_20241220.csv
# ✅ 20241221: saved 100 games → box-score-ids/espn_ncaam_box_scores_20241221.csv
# ✅ 20241222: saved 48 games → box-score-ids/espn_ncaam_box_scores_20241222.csv
# ✅ 20241223: saved 9 games → box-score-ids/espn_ncaam_box_scores_20241223.csv
# — 20241224: no games
# ✅ 20241225: saved 4 games → box-score-ids/espn_ncaam_box_scores_20241225.csv
# — 20241226: no games
# ✅ 20241227: saved 2 games → box-score-ids/espn_ncaam_box_scores_20241227.csv
# ✅ 20241228: saved 53 games → box-score-ids/espn_ncaam_box_scores_20241228.csv
# ✅ 20241229: saved 60 games → box-score-ids/espn_ncaam_box_scores_20241229.csv
# ✅ 20241230: saved 43 games → box-score-ids/espn_ncaam_box_scores_20241230.csv
# ✅ 20241231: saved 33 games → box-score-ids/espn_ncaam_box_scores_20241231.csv
# ✅ 20250101: saved 21 games → box-score-ids/espn_ncaam_box_scores_20250101.csv
# ✅ 20250102: saved 66 games → box-score-ids/espn_ncaam_box_scores_20250102.csv
# ✅ 20250103: saved 16 games → box-score-ids/espn_ncaam_box_scores_20250103.csv
# ✅ 20250104: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250104.csv
# ✅ 20250105: saved 27 games → box-score-ids/espn_ncaam_box_scores_20250105.csv
# ✅ 20250106: saved 16 games → box-score-ids/espn_ncaam_box_scores_20250106.csv
# ✅ 20250107: saved 34 games → box-score-ids/espn_ncaam_box_scores_20250107.csv
# ✅ 20250108: saved 50 games → box-score-ids/espn_ncaam_box_scores_20250108.csv
# ✅ 20250109: saved 55 games → box-score-ids/espn_ncaam_box_scores_20250109.csv
# — 20250110: no games
# ✅ 20250111: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250111.csv
# ✅ 20250112: saved 21 games → box-score-ids/espn_ncaam_box_scores_20250112.csv
# ✅ 20250113: saved 22 games → box-score-ids/espn_ncaam_box_scores_20250113.csv
# ✅ 20250114: saved 36 games → box-score-ids/espn_ncaam_box_scores_20250114.csv
# ✅ 20250115: saved 48 games → box-score-ids/espn_ncaam_box_scores_20250115.csv
# ✅ 20250116: saved 63 games → box-score-ids/espn_ncaam_box_scores_20250116.csv
# ✅ 20250117: saved 10 games → box-score-ids/espn_ncaam_box_scores_20250117.csv
# ✅ 20250118: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250118.csv
# ✅ 20250119: saved 11 games → box-score-ids/espn_ncaam_box_scores_20250119.csv
# ✅ 20250120: saved 29 games → box-score-ids/espn_ncaam_box_scores_20250120.csv
# ✅ 20250121: saved 35 games → box-score-ids/espn_ncaam_box_scores_20250121.csv
# ✅ 20250122: saved 42 games → box-score-ids/espn_ncaam_box_scores_20250122.csv
# ✅ 20250123: saved 61 games → box-score-ids/espn_ncaam_box_scores_20250123.csv
# ✅ 20250124: saved 14 games → box-score-ids/espn_ncaam_box_scores_20250124.csv
# ✅ 20250125: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250125.csv
# ✅ 20250126: saved 13 games → box-score-ids/espn_ncaam_box_scores_20250126.csv
# ✅ 20250127: saved 22 games → box-score-ids/espn_ncaam_box_scores_20250127.csv
# ✅ 20250128: saved 29 games → box-score-ids/espn_ncaam_box_scores_20250128.csv
# ✅ 20250129: saved 52 games → box-score-ids/espn_ncaam_box_scores_20250129.csv
# ✅ 20250130: saved 58 games → box-score-ids/espn_ncaam_box_scores_20250130.csv
# ✅ 20250131: saved 14 games → box-score-ids/espn_ncaam_box_scores_20250131.csv
# ✅ 20250201: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250201.csv
# ✅ 20250202: saved 19 games → box-score-ids/espn_ncaam_box_scores_20250202.csv
# ✅ 20250203: saved 21 games → box-score-ids/espn_ncaam_box_scores_20250203.csv
# ✅ 20250204: saved 34 games → box-score-ids/espn_ncaam_box_scores_20250204.csv
# ✅ 20250205: saved 55 games → box-score-ids/espn_ncaam_box_scores_20250205.csv
# ✅ 20250206: saved 59 games → box-score-ids/espn_ncaam_box_scores_20250206.csv
# ✅ 20250207: saved 7 games → box-score-ids/espn_ncaam_box_scores_20250207.csv
# ✅ 20250208: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250208.csv
# ✅ 20250209: saved 8 games → box-score-ids/espn_ncaam_box_scores_20250209.csv
# ✅ 20250210: saved 19 games → box-score-ids/espn_ncaam_box_scores_20250210.csv
# ✅ 20250211: saved 37 games → box-score-ids/espn_ncaam_box_scores_20250211.csv
# ✅ 20250212: saved 44 games → box-score-ids/espn_ncaam_box_scores_20250212.csv
# ✅ 20250213: saved 59 games → box-score-ids/espn_ncaam_box_scores_20250213.csv
# ✅ 20250214: saved 16 games → box-score-ids/espn_ncaam_box_scores_20250214.csv
# ✅ 20250215: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250215.csv
# ✅ 20250216: saved 25 games → box-score-ids/espn_ncaam_box_scores_20250216.csv
# ✅ 20250217: saved 21 games → box-score-ids/espn_ncaam_box_scores_20250217.csv
# ✅ 20250218: saved 32 games → box-score-ids/espn_ncaam_box_scores_20250218.csv
# ✅ 20250219: saved 51 games → box-score-ids/espn_ncaam_box_scores_20250219.csv
# ✅ 20250220: saved 52 games → box-score-ids/espn_ncaam_box_scores_20250220.csv
# ✅ 20250221: saved 20 games → box-score-ids/espn_ncaam_box_scores_20250221.csv
# ✅ 20250222: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250222.csv
# ✅ 20250223: saved 28 games → box-score-ids/espn_ncaam_box_scores_20250223.csv
# ✅ 20250224: saved 27 games → box-score-ids/espn_ncaam_box_scores_20250224.csv
# ✅ 20250225: saved 35 games → box-score-ids/espn_ncaam_box_scores_20250225.csv
# ✅ 20250226: saved 54 games → box-score-ids/espn_ncaam_box_scores_20250226.csv
# ✅ 20250227: saved 54 games → box-score-ids/espn_ncaam_box_scores_20250227.csv
# ✅ 20250228: saved 23 games → box-score-ids/espn_ncaam_box_scores_20250228.csv
# ✅ 20250301: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250301.csv
# ✅ 20250302: saved 23 games → box-score-ids/espn_ncaam_box_scores_20250302.csv
# ✅ 20250303: saved 27 games → box-score-ids/espn_ncaam_box_scores_20250303.csv
# ✅ 20250304: saved 44 games → box-score-ids/espn_ncaam_box_scores_20250304.csv
# ✅ 20250305: saved 31 games → box-score-ids/espn_ncaam_box_scores_20250305.csv
# ✅ 20250306: saved 53 games → box-score-ids/espn_ncaam_box_scores_20250306.csv
# ✅ 20250307: saved 31 games → box-score-ids/espn_ncaam_box_scores_20250307.csv
# ✅ 20250308: saved 100 games → box-score-ids/espn_ncaam_box_scores_20250308.csv
# ✅ 20250309: saved 29 games → box-score-ids/espn_ncaam_box_scores_20250309.csv
# ✅ 20250310: saved 12 games → box-score-ids/espn_ncaam_box_scores_20250310.csv
# ✅ 20250311: saved 24 games → box-score-ids/espn_ncaam_box_scores_20250311.csv
# ✅ 20250312: saved 40 games → box-score-ids/espn_ncaam_box_scores_20250312.csv
# ✅ 20250313: saved 48 games → box-score-ids/espn_ncaam_box_scores_20250313.csv
#
# Done. Wrote 5585 games across 127 days into 'box-score-ids/'.
