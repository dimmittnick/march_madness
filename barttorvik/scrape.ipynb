# %%
# pip install playwright bs4
# python -m playwright install
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "playwright", "install", "chromium"])

## 2021: 20201101 - 20220313

# %%
import asyncio, time
from typing import List
from playwright.async_api import async_playwright, TimeoutError as PWTimeout
from bs4 import BeautifulSoup

async def get_final_html(
    url: str,
    *,
    table_selector: str = "table",
    timeout_ms: int = 30000,
    headless: bool = True
) -> str:
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=headless)
        context = await browser.new_context(
            user_agent=("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                        "AppleWebKit/537.36 (KHTML, like Gecko) "
                        "Chrome/119.0.0.0 Safari/537.36"),
            locale="en-US",
            timezone_id="America/New_York",
        )
        page = await context.new_page()
        await page.goto(url, wait_until="domcontentloaded", timeout=timeout_ms)

        # Prefer: wait for the real table to show up
        try:
            await page.wait_for_selector(table_selector, timeout=20000)
        except PWTimeout:
            # Fallback: give network a chance to go idle, then re-check
            await page.wait_for_load_state("networkidle", timeout=10000)

        # If we still landed on the verification page, poll briefly
        for _ in range(6):
            html = await page.content()
            if ("Verifying your browser" not in html
                and "js_test_submitted" not in html):
                break
            await asyncio.sleep(1)

        final_html = await page.content()
        await browser.close()
        return final_html


def parse_first_table(html: str) -> List[List[str]]:
    soup = BeautifulSoup(html, "html.parser")
    table = soup.select_one("table")
    if not table:
        return []
    rows = []
    for tr in table.select("tr"):
        cells = [c.get_text(strip=True) for c in tr.select("th, td")]
        if cells:
            rows.append(cells)
    return rows

# --- How to call this ---

# 1) If you're already inside `async def` (FastAPI/Jupyter/etc):

async def scrape_table(url: str, table_selector="table"):
    html = await get_final_html(url, table_selector=table_selector, headless=True)
    rows = parse_first_table(html)
    return rows

rows = await scrape_table('https://barttorvik.com/trank.php?year=2021&sort=&hteam=&t2value=&conlimit=All&state=All&begin=20201101&end=20211110&top=0&revquad=0&quad=5&venue=All&type=All&mingames=0#', "table.your-selector")

# %%
import pandas as pd
# Use the second row as headers
columns = rows[1]

# Remaining rows are data (skip first 2 rows)
data = rows[2:]

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

print(df.shape)
df.head(10)
# Out:
# (376, 24)
#    Rk                           Team  Conf  G     Rec    AdjOE     AdjDE  \
# 0   1    Houston1 seed,Sweet Sixteen   B12  7  7–00–0  118.121     79.51
# 1   2            Purdue1 seed,Finals   B10  7  7–00–0  120.012     84.03
# 2   3    Arizona2 seed,Sweet Sixteen   P12  6  6–00–0   121.48     86.05
# 3   4       Connecticut1 seed,CHAMPS    BE  7  7–00–0   123.53    92.221
# 4   5                 BYU6 seed, R64   B12  6  6–00–0  120.411    90.011
# 5   6              Auburn4 seed, R64   SEC  6  5–10–0  115.832     87.69
# 6   7  Marquette2 seed,Sweet Sixteen    BE  7  6–10–0  117.025    90.917
# 7   8       Alabama4 seed,Final Four   SEC  7  5–20–0   130.51  101.7147
# 8   9    Florida Atlantic8 seed, R64  Amer  7  6–10–0   122.35    95.544
# 9  10              Baylor3 seed, R32   B12  6  6–00–0   127.42   99.7106
#
#    Barthag     EFG%    EFGD%  ...      FTR     FTRD      2P%     2P%D  \
# 0   .98961  51.2132    41.07  ...  36.2126  36.2229  50.8162   40.410
# 1   .98372   57.219   42.715  ...   46.320    18.43   53.395  47.7116
# 2   .98133   57.518   44.234  ...  37.1107   24.136   56.932   42.317
# 3   .96664   57.816   43.622  ...   38.182  30.2128    65.91    40.19
# 4   .96585   58.611   42.313  ...  26.1303   27.471   59.216   46.272
# 5   .96096  51.5125    40.54  ...   44.428  38.7269  52.4118   42.921
# 6   .94827   55.830  47.7105  ...  29.6258   25.246   60.510   46.169
# 7   .94578    59.55  51.6235  ...   48.313  35.6220   58.417  50.9200
# 8   .94529   57.915   46.879  ...  32.4210   28.087   57.423   46.894
# 9  .943810    59.08   46.879  ...   47.217  30.0122  52.3121  49.2149
#
#        3P%     3P%D      3PR     3PRD   Adj T.      WAB
# 0  34.6118   27.941  38.0164  41.3281  65.0338    +1.48
# 1    42.83    24.06  36.1211  43.0311  70.9127    +2.81
# 2   39.221  31.5129  31.3303  38.6221   75.410    +1.83
# 3  30.9236  34.1226   41.484   31.034  69.2201   +1.017
# 4   38.628    22.51    50.16   31.034   71.792   +1.212
# 5  33.3156    23.74  37.5175   33.692   73.046  +0.4836
# 6  32.8178  33.5203   41.680  38.3218  70.4147    +1.76
# 7   40.711  35.1254   41.974  36.1151   73.731  +0.0356
# 8   39.221  31.3125  39.8116  35.0123  68.4235   +1.019
# 9    48.71   28.044  32.5285   33.281   71.980    +1.75
#
# [10 rows x 24 columns]

# %%
# pip install playwright bs4 pandas python-dateutil
# python -m playwright install   # only once

import asyncio
import os
from datetime import datetime, timedelta
from typing import List
import pandas as pd
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PWTimeout

BASE_URL = (
    "https://barttorvik.com/trank.php"
    "?year={year}&sort=&hteam=&t2value=&conlimit=All&state=All"
    "&begin={begin}&end={end}&top=0&revquad=0&quad=5&venue=All&type=All&mingames=0#"
)

# ---------- HTML fetch ----------

async def goto_and_get_html(page, url: str, table_selector: str = "table", timeout_ms: int = 30000) -> str:
    await page.goto(url, wait_until="domcontentloaded", timeout=timeout_ms)
    try:
        await page.wait_for_selector(table_selector, timeout=20000)
    except PWTimeout:
        await page.wait_for_load_state("networkidle", timeout=10000)

    # if we’re still on the verification page, wait a bit
    for _ in range(6):
        html = await page.content()
        if "Verifying your browser" not in html and "js_test_submitted" not in html:
            break
        await asyncio.sleep(1)

    return await page.content()

# ---------- Table parsing ----------

def parse_first_table(html: str) -> List[List[str]]:
    soup = BeautifulSoup(html, "html.parser")
    table = soup.select_one("table")
    if not table:
        return []
    rows = []
    for tr in table.select("tr"):
        cells = [c.get_text(strip=True) for c in tr.select("th, td")]
        if cells:
            rows.append(cells)
    return rows


def rows_to_dataframe(rows: List[List[str]]) -> pd.DataFrame:
    """Convert raw scraped rows into a DataFrame"""
    if len(rows) < 3:
        return pd.DataFrame()
    columns = rows[1]  # second row = headers
    data = rows[2:]
    max_len = len(columns)
    norm = [r[:max_len] + ([""] * (max_len - len(r))) for r in data]
    df = pd.DataFrame(norm, columns=columns)
    return df

# ---------- Orchestrator ----------

async def scrape_barttorvik_daily(
    year: int = 2021,
    begin: str = "20201101",
    end: str = "20210313",
    output_dir: str = "daily_csvs",
    master_csv: str = "barttorvik_2021_all.csv",
    table_selector: str = "table",
    headless: bool = True,
    pause_sec: float = 3.8
):
    os.makedirs(output_dir, exist_ok=True)
    start_dt = datetime.strptime(begin, "%Y%m%d")
    final_dt = datetime.strptime(end, "%Y%m%d")

    first_write = not os.path.exists(master_csv)

    async with async_playwright() as p:
        browser = await p.chromium.launch(channel="chrome", headless=headless)
        context = await browser.new_context(
            user_agent=("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                        "AppleWebKit/537.36 (KHTML, like Gecko) "
                        "Chrome/119.0.0.0 Safari/537.36"),
            locale="en-US",
            timezone_id="America/New_York",
        )
        page = await context.new_page()

        dt = start_dt
        total_rows = 0
        while dt <= final_dt:
            end_str = dt.strftime("%Y%m%d")
            url = BASE_URL.format(year=year, begin=begin, end=end_str)

            try:
                html = await goto_and_get_html(page, url, table_selector=table_selector)
                rows = parse_first_table(html)
                df = rows_to_dataframe(rows)

                if not df.empty:
                    df.insert(0, "Date", end_str)

                    # write individual daily file
                    daily_path = os.path.join(output_dir, f"barttorvik_{end_str}.csv")
                    df.to_csv(daily_path, index=False)
                    print(f"✔️  {end_str}: saved {len(df)} rows to {daily_path}")

                    # append to master CSV
                    if first_write:
                        df.to_csv(master_csv, index=False)
                        first_write = False
                    else:
                        df.to_csv(master_csv, mode="a", header=False, index=False)

                    total_rows += len(df)
                else:
                    print(f"⚠️  {end_str}: no data (empty table)")

            except Exception as e:
                print(f"❌ {end_str}: ERROR {e}")

            await asyncio.sleep(pause_sec)
            dt += timedelta(days=1)

        await browser.close()

    print(f"\n✅ Done! {total_rows} total rows saved across days.")

# ---------- Run ----------
# In Jupyter or async environment:
await scrape_barttorvik_daily(
    year=2025,
    begin="20241103",
    end="20250318",
    output_dir="daily_csvs_2025",
    master_csv="barttorvik_2025_all.csv"
)
# Out:
# ✔️  20241103: saved 1 rows to daily_csvs_2025/barttorvik_20241103.csv
# ✔️  20241104: saved 242 rows to daily_csvs_2025/barttorvik_20241104.csv
# ✔️  20241105: saved 258 rows to daily_csvs_2025/barttorvik_20241105.csv
# ✔️  20241106: saved 288 rows to daily_csvs_2025/barttorvik_20241106.csv
# ✔️  20241107: saved 301 rows to daily_csvs_2025/barttorvik_20241107.csv
# ✔️  20241108: saved 341 rows to daily_csvs_2025/barttorvik_20241108.csv
# ✔️  20241109: saved 367 rows to daily_csvs_2025/barttorvik_20241109.csv
# ✔️  20241110: saved 372 rows to daily_csvs_2025/barttorvik_20241110.csv
# ✔️  20241111: saved 375 rows to daily_csvs_2025/barttorvik_20241111.csv
# ✔️  20241112: saved 377 rows to daily_csvs_2025/barttorvik_20241112.csv
# ✔️  20241113: saved 377 rows to daily_csvs_2025/barttorvik_20241113.csv
# ✔️  20241114: saved 377 rows to daily_csvs_2025/barttorvik_20241114.csv
# ✔️  20241115: saved 377 rows to daily_csvs_2025/barttorvik_20241115.csv
# ✔️  20241116: saved 378 rows to daily_csvs_2025/barttorvik_20241116.csv
# ✔️  20241117: saved 378 rows to daily_csvs_2025/barttorvik_20241117.csv
# ✔️  20241118: saved 378 rows to daily_csvs_2025/barttorvik_20241118.csv
# ✔️  20241119: saved 378 rows to daily_csvs_2025/barttorvik_20241119.csv
# ✔️  20241120: saved 378 rows to daily_csvs_2025/barttorvik_20241120.csv
# ✔️  20241121: saved 378 rows to daily_csvs_2025/barttorvik_20241121.csv
# ✔️  20241122: saved 378 rows to daily_csvs_2025/barttorvik_20241122.csv
# ✔️  20241123: saved 378 rows to daily_csvs_2025/barttorvik_20241123.csv
# ✔️  20241124: saved 378 rows to daily_csvs_2025/barttorvik_20241124.csv
# ✔️  20241125: saved 378 rows to daily_csvs_2025/barttorvik_20241125.csv
# ✔️  20241126: saved 378 rows to daily_csvs_2025/barttorvik_20241126.csv
# ✔️  20241127: saved 378 rows to daily_csvs_2025/barttorvik_20241127.csv
# ✔️  20241128: saved 378 rows to daily_csvs_2025/barttorvik_20241128.csv
# ✔️  20241129: saved 378 rows to daily_csvs_2025/barttorvik_20241129.csv
# ✔️  20241130: saved 378 rows to daily_csvs_2025/barttorvik_20241130.csv
# ✔️  20241201: saved 378 rows to daily_csvs_2025/barttorvik_20241201.csv
# ✔️  20241202: saved 378 rows to daily_csvs_2025/barttorvik_20241202.csv
# ✔️  20241203: saved 378 rows to daily_csvs_2025/barttorvik_20241203.csv
# ✔️  20241204: saved 378 rows to daily_csvs_2025/barttorvik_20241204.csv
# ✔️  20241205: saved 378 rows to daily_csvs_2025/barttorvik_20241205.csv
# ✔️  20241206: saved 378 rows to daily_csvs_2025/barttorvik_20241206.csv
# ✔️  20241207: saved 378 rows to daily_csvs_2025/barttorvik_20241207.csv
# ✔️  20241208: saved 378 rows to daily_csvs_2025/barttorvik_20241208.csv
# ✔️  20241209: saved 378 rows to daily_csvs_2025/barttorvik_20241209.csv
# ✔️  20241210: saved 378 rows to daily_csvs_2025/barttorvik_20241210.csv
# ✔️  20241211: saved 378 rows to daily_csvs_2025/barttorvik_20241211.csv
# ✔️  20241212: saved 378 rows to daily_csvs_2025/barttorvik_20241212.csv
# ✔️  20241213: saved 378 rows to daily_csvs_2025/barttorvik_20241213.csv
# ✔️  20241214: saved 378 rows to daily_csvs_2025/barttorvik_20241214.csv
# ✔️  20241215: saved 378 rows to daily_csvs_2025/barttorvik_20241215.csv
# ✔️  20241216: saved 378 rows to daily_csvs_2025/barttorvik_20241216.csv
# ✔️  20241217: saved 378 rows to daily_csvs_2025/barttorvik_20241217.csv
# ✔️  20241218: saved 378 rows to daily_csvs_2025/barttorvik_20241218.csv
# ✔️  20241219: saved 378 rows to daily_csvs_2025/barttorvik_20241219.csv
# ✔️  20241220: saved 378 rows to daily_csvs_2025/barttorvik_20241220.csv
# ✔️  20241221: saved 378 rows to daily_csvs_2025/barttorvik_20241221.csv
# ✔️  20241222: saved 378 rows to daily_csvs_2025/barttorvik_20241222.csv
# ✔️  20241223: saved 378 rows to daily_csvs_2025/barttorvik_20241223.csv
# ✔️  20241224: saved 378 rows to daily_csvs_2025/barttorvik_20241224.csv
# ✔️  20241225: saved 378 rows to daily_csvs_2025/barttorvik_20241225.csv
# ✔️  20241226: saved 378 rows to daily_csvs_2025/barttorvik_20241226.csv
# ✔️  20241227: saved 378 rows to daily_csvs_2025/barttorvik_20241227.csv
# ✔️  20241228: saved 378 rows to daily_csvs_2025/barttorvik_20241228.csv
# ✔️  20241229: saved 378 rows to daily_csvs_2025/barttorvik_20241229.csv
# ✔️  20241230: saved 378 rows to daily_csvs_2025/barttorvik_20241230.csv
# ✔️  20241231: saved 378 rows to daily_csvs_2025/barttorvik_20241231.csv
# ✔️  20250101: saved 378 rows to daily_csvs_2025/barttorvik_20250101.csv
# ✔️  20250102: saved 378 rows to daily_csvs_2025/barttorvik_20250102.csv
# ✔️  20250103: saved 378 rows to daily_csvs_2025/barttorvik_20250103.csv
# ✔️  20250104: saved 378 rows to daily_csvs_2025/barttorvik_20250104.csv
# ✔️  20250105: saved 378 rows to daily_csvs_2025/barttorvik_20250105.csv
# ✔️  20250106: saved 378 rows to daily_csvs_2025/barttorvik_20250106.csv
# ✔️  20250107: saved 378 rows to daily_csvs_2025/barttorvik_20250107.csv
# ✔️  20250108: saved 378 rows to daily_csvs_2025/barttorvik_20250108.csv
# ✔️  20250109: saved 378 rows to daily_csvs_2025/barttorvik_20250109.csv
# ✔️  20250110: saved 378 rows to daily_csvs_2025/barttorvik_20250110.csv
# ✔️  20250111: saved 378 rows to daily_csvs_2025/barttorvik_20250111.csv
# ✔️  20250112: saved 378 rows to daily_csvs_2025/barttorvik_20250112.csv
# ✔️  20250113: saved 378 rows to daily_csvs_2025/barttorvik_20250113.csv
# ✔️  20250114: saved 378 rows to daily_csvs_2025/barttorvik_20250114.csv
# ✔️  20250115: saved 378 rows to daily_csvs_2025/barttorvik_20250115.csv
# ✔️  20250116: saved 378 rows to daily_csvs_2025/barttorvik_20250116.csv
# ✔️  20250117: saved 378 rows to daily_csvs_2025/barttorvik_20250117.csv
# ✔️  20250118: saved 378 rows to daily_csvs_2025/barttorvik_20250118.csv
# ✔️  20250119: saved 378 rows to daily_csvs_2025/barttorvik_20250119.csv
# ✔️  20250120: saved 378 rows to daily_csvs_2025/barttorvik_20250120.csv
# ✔️  20250121: saved 378 rows to daily_csvs_2025/barttorvik_20250121.csv
# ✔️  20250122: saved 378 rows to daily_csvs_2025/barttorvik_20250122.csv
# ✔️  20250123: saved 378 rows to daily_csvs_2025/barttorvik_20250123.csv
# ✔️  20250124: saved 378 rows to daily_csvs_2025/barttorvik_20250124.csv
# ✔️  20250125: saved 378 rows to daily_csvs_2025/barttorvik_20250125.csv
# ✔️  20250126: saved 378 rows to daily_csvs_2025/barttorvik_20250126.csv
# ✔️  20250127: saved 378 rows to daily_csvs_2025/barttorvik_20250127.csv
# ✔️  20250128: saved 378 rows to daily_csvs_2025/barttorvik_20250128.csv
# ✔️  20250129: saved 378 rows to daily_csvs_2025/barttorvik_20250129.csv
# ✔️  20250130: saved 378 rows to daily_csvs_2025/barttorvik_20250130.csv
# ✔️  20250131: saved 378 rows to daily_csvs_2025/barttorvik_20250131.csv
# ✔️  20250201: saved 378 rows to daily_csvs_2025/barttorvik_20250201.csv
# ✔️  20250202: saved 378 rows to daily_csvs_2025/barttorvik_20250202.csv
# ✔️  20250203: saved 378 rows to daily_csvs_2025/barttorvik_20250203.csv
# ✔️  20250204: saved 378 rows to daily_csvs_2025/barttorvik_20250204.csv
# ✔️  20250205: saved 378 rows to daily_csvs_2025/barttorvik_20250205.csv
# ✔️  20250206: saved 378 rows to daily_csvs_2025/barttorvik_20250206.csv
# ✔️  20250207: saved 378 rows to daily_csvs_2025/barttorvik_20250207.csv
# ✔️  20250208: saved 378 rows to daily_csvs_2025/barttorvik_20250208.csv
# ✔️  20250209: saved 378 rows to daily_csvs_2025/barttorvik_20250209.csv
# ✔️  20250210: saved 378 rows to daily_csvs_2025/barttorvik_20250210.csv
# ✔️  20250211: saved 378 rows to daily_csvs_2025/barttorvik_20250211.csv
# ✔️  20250212: saved 378 rows to daily_csvs_2025/barttorvik_20250212.csv
# ✔️  20250213: saved 378 rows to daily_csvs_2025/barttorvik_20250213.csv
# ✔️  20250214: saved 378 rows to daily_csvs_2025/barttorvik_20250214.csv
# ✔️  20250215: saved 378 rows to daily_csvs_2025/barttorvik_20250215.csv
# ✔️  20250216: saved 378 rows to daily_csvs_2025/barttorvik_20250216.csv
# ✔️  20250217: saved 378 rows to daily_csvs_2025/barttorvik_20250217.csv
# ✔️  20250218: saved 378 rows to daily_csvs_2025/barttorvik_20250218.csv
# ✔️  20250219: saved 378 rows to daily_csvs_2025/barttorvik_20250219.csv
# ✔️  20250220: saved 378 rows to daily_csvs_2025/barttorvik_20250220.csv
# ✔️  20250221: saved 378 rows to daily_csvs_2025/barttorvik_20250221.csv
# ✔️  20250222: saved 378 rows to daily_csvs_2025/barttorvik_20250222.csv
# ✔️  20250223: saved 378 rows to daily_csvs_2025/barttorvik_20250223.csv
# ✔️  20250224: saved 378 rows to daily_csvs_2025/barttorvik_20250224.csv
# ✔️  20250225: saved 378 rows to daily_csvs_2025/barttorvik_20250225.csv
# ✔️  20250226: saved 378 rows to daily_csvs_2025/barttorvik_20250226.csv
# ✔️  20250227: saved 378 rows to daily_csvs_2025/barttorvik_20250227.csv
# ✔️  20250228: saved 378 rows to daily_csvs_2025/barttorvik_20250228.csv
# ✔️  20250301: saved 378 rows to daily_csvs_2025/barttorvik_20250301.csv
# ✔️  20250302: saved 378 rows to daily_csvs_2025/barttorvik_20250302.csv
# ✔️  20250303: saved 378 rows to daily_csvs_2025/barttorvik_20250303.csv
# ✔️  20250304: saved 378 rows to daily_csvs_2025/barttorvik_20250304.csv
# ✔️  20250305: saved 378 rows to daily_csvs_2025/barttorvik_20250305.csv
# ✔️  20250306: saved 378 rows to daily_csvs_2025/barttorvik_20250306.csv
# ✔️  20250307: saved 378 rows to daily_csvs_2025/barttorvik_20250307.csv
# ✔️  20250308: saved 378 rows to daily_csvs_2025/barttorvik_20250308.csv
# ✔️  20250309: saved 378 rows to daily_csvs_2025/barttorvik_20250309.csv
# ✔️  20250310: saved 378 rows to daily_csvs_2025/barttorvik_20250310.csv
# ✔️  20250311: saved 378 rows to daily_csvs_2025/barttorvik_20250311.csv
# ✔️  20250312: saved 378 rows to daily_csvs_2025/barttorvik_20250312.csv
# ✔️  20250313: saved 378 rows to daily_csvs_2025/barttorvik_20250313.csv
# ✔️  20250314: saved 378 rows to daily_csvs_2025/barttorvik_20250314.csv
# ✔️  20250315: saved 378 rows to daily_csvs_2025/barttorvik_20250315.csv
# ✔️  20250316: saved 378 rows to daily_csvs_2025/barttorvik_20250316.csv
# ✔️  20250317: saved 378 rows to daily_csvs_2025/barttorvik_20250317.csv
# ✔️  20250318: saved 378 rows to daily_csvs_2025/barttorvik_20250318.csv
#
# ✅ Done! 50547 total rows saved across days.
